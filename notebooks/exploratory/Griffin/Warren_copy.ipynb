# %% [markdown]
# Importing packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Reading in the data

# %%
df = pd.read_csv('../../../data/WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
# df['TotalCharges'].str.astype(float)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
#label encode Churn
#binary encode the yes/no
#one hot encode the rest

# %%
sns.pairplot(df)

# %%
df.columns = df.columns.str.lower()

# %%
for col in df.columns:
    print(col,df[col].nunique())
# Out:
# customerid 7043
# gender 2
# seniorcitizen 2
# partner 2
# dependents 2
# tenure 73
# phoneservice 2
# multiplelines 3
# internetservice 3
# onlinesecurity 3
# onlinebackup 3
# deviceprotection 3
# techsupport 3
# streamingtv 3
# streamingmovies 3
# contract 3
# paperlessbilling 2
# paymentmethod 4
# monthlycharges 1585
# totalcharges 6530
# churn 2

# %% [markdown]
# Spliting the data for encoding and scaling

# %%
cust_id = df['customerid']
df = df.drop('customerid',axis=1)

# %%
df['num_of_ser_times_tot_charges'] = df['num_of_services'] * df['totalcharges']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'num_of_services'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-428b0776f962> in <module>
# ...

# %%
ord_encode = ['gender','partner','dependents','phoneservice','multiplelines','internetservice','onlinesecurity','onlinebackup',
              'deviceprotection','techsupport','streamingtv','streamingmovies','contract','paperlessbilling','paymentmethod', 'seniorcitizen', 'single_parent', 'phone_and_internet']
labelencode =['churn']
num = ['tenure','monthlycharges','totalcharges' 'num_of_ser_times_tot_charges']

# %%
X = df[ord_encode].join(df[num],how='left')
y = df[labelencode]

from sklearn.model_selection import train_test_split

X_t, X_test, y_t, y_test = train_test_split(X,y,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-d79776cc9870> in <module>
# ----> 1 X = df[ord_encode].join(df[num],how='left')
#       2 y = df[labelencode]
#       3
#       4 from sklearn.model_selection import train_test_split
#       5
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# ...

# %%
X_train, X_val, y_train, y_val = train_test_split(X_t,y_t,random_state=0)

# %% [markdown]
# Impute missing values as 0

# %%
from sklearn.impute import SimpleImputer

impute = SimpleImputer(strategy='constant',fill_value=0)
X_train_im = impute.fit_transform(X_train)
X_val_im = impute.transform(X_val)

X_train_im = pd.DataFrame(X_train_im,columns=X.columns)
X_val_im = pd.DataFrame(X_val_im,columns=X.columns)

# %%
from sklearn.preprocessing import OrdinalEncoder
#ord encode categoticals
ordi = OrdinalEncoder(dtype=np.int)

X_train_ord = ordi.fit_transform(X_train_im[ord_encode])
X_val_ord = ordi.transform(X_val_im[ord_encode])

X_train_ord = pd.DataFrame(X_train_ord,columns=X[ord_encode].columns)
X_val_ord = pd.DataFrame(X_val_ord,columns=X[ord_encode].columns)

from sklearn.preprocessing import StandardScaler
#scale numerical
#use median for limit effect of outliers
ss = StandardScaler()

X_train_num = ss.fit_transform(X_train_im[num])
X_val_num = ss.transform(X_val_im[num])

X_train_num = pd.DataFrame(X_train_num,columns=X[num].columns)
X_val_num = pd.DataFrame(X_val_num,columns=X[num].columns)

# %%
X_train_num

# %%
#combine the categorical and numerical dfs

X_train_sc = X_train_ord.join(X_train_num,how='left')
X_val_sc = X_val_ord.join(X_val_num,how='left')

# %%
#encode the labels

from sklearn.preprocessing import LabelEncoder

lbl = LabelEncoder()

y_train = lbl.fit_transform(np.array(y_train))
y_val = lbl.transform(y_val)

y_train_enc = pd.DataFrame(y_train,columns=y.columns)
y_val_enc = pd.DataFrame(y_val,columns=y.columns)

# %%
y_val_enc

# %%
X_train_sc.to_csv('X_train_sc.csv',index=False)
X_val_sc.to_csv('X_val_sc.csv',index=False)

y_train_enc.to_csv('y_train_enc.csv',index=False)
y_val_enc.to_csv('y_val_enc.csv',index=False)

# %%
df

# %% [markdown]
# Visual for the rate at which people who are senior citizens did not churn

# %%
sns.barplot(x=df['seniorcitizen']==0, y=df['churn'])
# Out:
# <AxesSubplot:xlabel='seniorcitizen', ylabel='churn'>

# %% [markdown]
# Visual for the rate at which people who are senior citizens did churn

# %%
sns.barplot(x=df['seniorcitizen']==1, y=df['churn'])
# Out:
# <AxesSubplot:xlabel='seniorcitizen', ylabel='churn'>

# %%
df[(df['seniorcitizen']==1) & (df['churn']=='Yes')]
#df[(df['age'] >= 60) & (df['rest_bp'] > 170)]
# Out:
#       gender  seniorcitizen partner dependents  tenure phoneservice  \
# 20      Male              1      No         No       1           No
# 53    Female              1     Yes         No       8          Yes
# 55      Male              1      No         No      18          Yes
# 99    Female              1     Yes         No      25          Yes
# 113   Female              1     Yes         No      37          Yes
# ...      ...            ...     ...        ...     ...          ...
# 6993  Female              1     Yes         No      50          Yes
# 7008  Female              1      No         No       3          Yes
# 7010  Female              1     Yes         No       1          Yes
# 7032    Male              1      No         No       1          Yes
# 7041    Male              1     Yes         No       4          Yes
#
#          multiplelines internetservice onlinesecurity onlinebackup  \
# 20    No phone service             DSL             No           No
# ...

# %%
single_parent = df[(df['partner']=='No') & (df['dependents']=='Yes')]

# %%
df
# Out:
#       gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          multiplelines internetservice onlinesecurity onlinebackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %% [markdown]
# Creating a column for single parents

# %%
df['partner_cont'] = df['partner'].map({'No': 0, 'Yes': 1, })

# %%
df['dependent_cont'] = df['dependents'].map({'No': 0, 'Yes': 1, })

# %%
df['single_parent'] = df['partner_cont'] + df['dependent_cont']

# %%
df['single_parent'] = df['single_parent'].map({1: 'No', 0: 'No', 2: 'Yes' })

# %%
df.drop(['partner_cont', 'dependent_cont'], axis=1, inplace=True)

# %% [markdown]
# Creating a column for people who used Telco for both phone and internet service

# %%
df['phone_count'] = df['phoneservice'].map({'No': 0, 'Yes': 1, })

# %%
df['internet_count'] = df['internetservice'].map({'No': 0, 'DSL': 1, 'Fiber optic': 1 })

# %%
df['phone_and_internet'] = df['phone_count'] + df['internet_count']

# %%
df['phone_and_internet'] = df['phone_and_internet'].map({1: 'No', 0: 'No', 2: 'Yes' })

# %%
df.drop(['phone_count', 'internet_count'], axis=1, inplace=True)

# %%
df
# Out:
#       gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          multiplelines internetservice onlinesecurity onlinebackup  ...  \
# 0     No phone service             DSL             No          Yes  ...
# ...

# %% [markdown]
# Creating a column for the number of additional services people used

# %%
df['o_sec'] = df['onlinesecurity'].map({'No': 0, 'Yes': 1})

# %%
df['o_back'] = df['onlinebackup'].map({'No': 0, 'Yes': 1})

# %%
df['t_sup'] = df['techsupport'].map({'No': 0, 'Yes': 1})

# %%
df['tv'] = df['streamingtv'].map({'No': 0, 'Yes': 1})

# %%
df['movie'] = df['streamingmovies'].map({'No': 0, 'Yes': 1})

# %%
df['protect'] = df['deviceprotection'].map({'No': 0, 'Yes': 1})

# %%
df['num_of_internet_services'] = df['o_sec'] + df['o_back'] + df['t_sup'] + df['tv'] + df['movie']

# %%
df['num_of_services'] = df['num_of_internet_services'] + df['protect']

# %%
df.drop(['o_back', 't_sup', 'tv', 'movie'], axis=1, inplace=True)

# %%
df.drop('o_sec', axis=1, inplace=True)

# %%
df['num_of_services'].value_counts()
# Out:
# 3.0    1118
# 2.0    1033
# 1.0     966
# 4.0     852
# 0.0     693
# 5.0     571
# 6.0     284
# Name: num_of_services, dtype: int64

# %%
df['churn_num'] = df['churn'].map({'No': 1, 'Yes': 2})

# %%
df['internet_yn'] = df['internetservice'].map({'Fiber optic': 'Yes', 'DSL': 'Yes', 'No': 'No'})

# %%
df['phoneservice'].value_counts()
# Out:
# Yes    6361
# No      682
# Name: phoneservice, dtype: int64

# %%
pd.DataFrame(df.groupby(['num_of_services', 'churn_num']).size()).reset_index().pivot(index='num_of_services', columns='churn_num',
                                                                                     values=0).plot(kind='bar', title='Churn by Number of Services Used', ylabel='Customers Who Churned', xlabel='Number of Services')
# Out:
# <AxesSubplot:title={'center':'Churn by Number of Services Used'}, xlabel='Number of Services', ylabel='Customers Who Churned'>

# %%
sns.set()

# %% [markdown]
# Creating a visual of the amount of people who churned and did not churn based on the number of additional services they used

# %%
pd.DataFrame(df.groupby(['num_of_services', 'churn']).size()).reset_index().pivot(index='num_of_services', columns='churn',
                                                                                     values=0).plot(kind='bar', title='Churn by Number of Services Used', ylabel='Customers Who Churned', xlabel='Number of Services', rot=0)
# Out:
# <AxesSubplot:title={'center':'Churn by Number of Services Used'}, xlabel='Number of Services', ylabel='Customers Who Churned'>

# %% [raw]
# Creating a visual of the amount of people who churned and did not churn based on the base services they used. (Phone, Internet, or both)

# %%
pd.DataFrame(df.groupby(['internet_yn', 'phoneservice', 'churn']).size()).reset_index().pivot(index='churn', columns=['internet_yn', 'phoneservice'],
                                                                                     values=0).plot(kind='bar', title='Churn by Internet and Phone Service', ylabel='Customers Who Churned', xlabel='Churn')
# Out:
# <AxesSubplot:title={'center':'Churn by Internet and Phone Service'}, xlabel='Churn', ylabel='Customers Who Churned'>

# %%
pd.DataFrame(df.groupby(['internet_yn', 'phoneservice', 'contract', 'churn']).size()).reset_index().pivot(index='churn', columns=['internet_yn', 'phoneservice', 'contract'],
                                                                                     values=0).T
# Out:
# churn                                      No   Yes
# internet_yn phoneservice contract
# No          Yes          Month-to-month   425    99
#                          One year         355     9
#                          Two year         633     5
# Yes         No           Month-to-month   223   153
#                          One year         131    14
#                          Two year         158     3
#             Yes          Month-to-month  1572  1403
#                          One year         821   143
#                          Two year         856    40

# %%
99 / (425 + 99)
# Out:
# 0.18893129770992367

# %%
(pd.DataFrame(df.groupby(['internet_yn', 'phoneservice', 'contract', 'churn']).size()).reset_index().pivot(index='churn', columns=['internet_yn', 'phoneservice', 'contract'],
                                                                                     values=0)/pd.DataFrame(df.groupby(['internet_yn', 'phoneservice', 'contract', 'churn']).size()).reset_index().pivot(index='churn', columns=['internet_yn', 'phoneservice', 'contract'],
                                                                                     values=0).T.sum(axis=1)).T.plot(kind='bar', figsize=(15,6), title='Churn by Internet and Phone Service', ylabel='Probability of Churning', xlabel='Service Type (Internet, Phone, Contract type)', rot=70)
# Out:
# <AxesSubplot:title={'center':'Churn by Internet and Phone Service'}, xlabel='Service Type (Internet, Phone, Contract type)', ylabel='Probability of Churning'>

# %%
pd.DataFrame(df.groupby(['internet_yn', 'phoneservice', 'contract', 'churn']).size()).reset_index().pivot(index='churn', columns=['internet_yn', 'phoneservice', 'contract'],
                                                                                     values=0).plot(kind='bar', title='Churn by Internet and Phone Service', ylabel='Customers Who Churned',
                                                                                                    xlabel='Churn', legend=True, fontsize=12, figsize=(15,6), rot=0).set_title('Churn by Internet and Phone Service', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Churn by Internet and Phone Service')

# %% [markdown]
# Creating a visual of the rate of people who churned or didnt churn based on the number of services they use

# %%
sns.barplot(x=df['num_of_services'], y=df['churn']).plot()
# Out:
# <AxesSubplot:xlabel='num_of_services', ylabel='churn'>

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'seniorcitizen'}>,
#         <AxesSubplot:title={'center':'tenure'}>,
#         <AxesSubplot:title={'center':'monthlycharges'}>],
#        [<AxesSubplot:title={'center':'totalcharges'}>,
#         <AxesSubplot:title={'center':'protect'}>,
#         <AxesSubplot:title={'center':'num_of_internet_services'}>],
#        [<AxesSubplot:title={'center':'num_of_services'}>,
#         <AxesSubplot:title={'center':'churn_num'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# Checking the corrolation between features

# %%
df.corr()
# Out:
#                           seniorcitizen    tenure  monthlycharges  \
# seniorcitizen                  1.000000  0.016567        0.220173
# tenure                         0.016567  1.000000        0.247900
# monthlycharges                 0.220173  0.247900        1.000000
# totalcharges                   0.102411  0.825880        0.651065
# protect                       -0.011482  0.421932        0.321927
# num_of_internet_services      -0.054380  0.625231        0.521809
# num_of_services               -0.049460  0.653279        0.536399
# churn_num                      0.150889 -0.352229        0.193356
#
#                           totalcharges   protect  num_of_internet_services  \
# seniorcitizen                 0.102411 -0.011482                 -0.054380
# tenure                        0.825880  0.421932                  0.625231
# monthlycharges                0.651065  0.321927                  0.521809
# ...

# %% [markdown]
# Creating new features by multiplying columns together

# %%
df['num_of_ser_times_tot_charges'] = df['num_of_services'] * df['totalcharges']

# %%
df['tenure_times_tot_charges'] = df['tenure'] * df['totalcharges']

# %%
df
# Out:
#       gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          multiplelines internetservice onlinesecurity onlinebackup  ... churn  \
# ...
